# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd

# %%
csv_path = '/home/linnanchen/code/MagicaBleps/UK-road-safety/raw_data'

# %%
df_accident = pd.read_csv(os.path.join(csv_path, 'dft-road-casualty-statistics-accident-1979-2021.csv'))
df_accident.head()
# Out:
# /tmp/ipykernel_25868/209948914.py:1: DtypeWarning: Columns (0,2,15,16,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_accident = pd.read_csv(os.path.join(csv_path, 'dft-road-casualty-statistics-accident-1979-2021.csv'))
#   accident_index  accident_year accident_reference  location_easting_osgr  \
# 0  197901A11AD14           1979          01A11AD14                    NaN
# 1  197901A1BAW34           1979          01A1BAW34               198460.0
# 2  197901A1BFD77           1979          01A1BFD77               406380.0
# 3  197901A1BGC20           1979          01A1BGC20               281680.0
# 4  197901A1BGF95           1979          01A1BGF95               153960.0
#
#    location_northing_osgr  longitude  latitude  police_force  \
# 0                     NaN        NaN       NaN             1
# 1                894000.0        NaN       NaN             1
# 2                307000.0        NaN       NaN             1
# ...

# %%
df_casualty = pd.read_csv(os.path.join(csv_path, 'dft-road-casualty-statistics-casualty-1979-2021.csv'))
df_casualty.head()
# Out:
# /tmp/ipykernel_25868/911384059.py:1: DtypeWarning: Columns (0,2,18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_casualty = pd.read_csv(os.path.join(csv_path, 'dft-road-casualty-statistics-casualty-1979-2021.csv'))
#   accident_index  accident_year accident_reference  vehicle_reference  \
# 0  197901A11AD14           1979          01A11AD14                  2
# 1  197901A1BAW34           1979          01A1BAW34                  1
# 2  197901A1BFD77           1979          01A1BFD77                  1
# 3  197901A1BFD77           1979          01A1BFD77                  1
# 4  197901A1BFD77           1979          01A1BFD77                  2
#
#    casualty_reference  casualty_class  sex_of_casualty  age_of_casualty  \
# 0                   1               1                1               -1
# 1                   1               3                2               27
# 2                   1               1                1               21
# ...

# %%
#df_vehicle = pd.read_csv(os.path.join(csv_path, 'dft-road-casualty-statistics-vehicle-1979-2021.csv'))

# %%
df_accident = df_accident[df_accident['accident_year'] >= 2018]
df_accident.head()
# Out:
#         accident_index  accident_year accident_reference  \
# 8271454  2018010080971           2018          010080971
# 8271455  2018010080973           2018          010080973
# 8271456  2018010080974           2018          010080974
# 8271457  2018010080981           2018          010080981
# 8271458  2018010080982           2018          010080982
#
#          location_easting_osgr  location_northing_osgr  longitude   latitude  \
# 8271454               529150.0                182270.0  -0.139737  51.524587
# 8271455               542020.0                184290.0   0.046471  51.539651
# 8271456               531720.0                182910.0  -0.102474  51.529746
# 8271457               541450.0                183220.0   0.037828  51.530179
# 8271458               543580.0                176500.0   0.065781  51.469258
#
#          police_force  accident_severity  number_of_vehicles  ...  \
# 8271454             1                  3                   2  ...
# ...

# %%
df_accident.shape
# Out:
# (839116, 36)

# %%
df_accident.isnull().sum()
# Out:
# accident_index                                   0
# accident_year                                    0
# accident_reference                               0
# location_easting_osgr                          114
# location_northing_osgr                         114
# longitude                                      114
# latitude                                       114
# police_force                                     0
# accident_severity                                0
# number_of_vehicles                               0
# number_of_casualties                             0
# date                                             0
# day_of_week                                      0
# time                                             0
# local_authority_district                         0
# local_authority_ons_district                     0
# local_authority_highway                          0
# first_road_class                                 0
# ...
